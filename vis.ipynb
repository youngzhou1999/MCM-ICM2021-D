# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df
# Out:
#                  0         1
# 0       Electronic  1.231888
# 1           Reggae  1.127302
# 2          Country  0.831785
# 3   Stage & Screen  1.295290
# 4   Easy Listening  1.255378
# 5             Folk  1.029906
# 6    Comedy/Spoken  1.334305
# 7          New Age  1.350377
# 8            Latin  1.070001
# 9        Classical  1.309529
# 10            R&B;  1.012033
# 11     Avant-Garde  1.715128
# 12           Vocal  0.966640
# 13            Jazz  1.110063
# 14           Blues  1.100032
# 15      Children's  2.245905
# 16   International  1.195133
# 17        Pop/Rock  0.910744
# 18       Religious  1.031763

# %%
df = pd.read_csv('1.txt',header=None)
df = df.sort_values(by=1,ascending = True)
df_ve = df.to_numpy()

# %%
df_ve
# Out:
# array([['Country', 0.8317853786074526],
#        ['Pop/Rock', 0.9107435203982918],
#        ['Vocal', 0.9666402250712188],
#        ['R&B;', 1.0120333626117148],
#        ['Folk', 1.0299059370121586],
#        ['Religious', 1.0317634020434578],
#        ['Latin', 1.0700005479159689],
#        ['Blues', 1.1000319164661656],
#        ['Jazz', 1.110062649575567],
#        ['Reggae', 1.1273024507970677],
#        ['International', 1.195133407856504],
#        ['Electronic', 1.2318884331018078],
#        ['Easy Listening', 1.25537810823876],
#        ['Stage & Screen', 1.2952897060238486],
#        ['Classical', 1.3095291007830403],
#        ['Comedy/Spoken', 1.3343045280277874],
#        ['New Age', 1.3503771371481017],
#        ['Avant-Garde', 1.7151276135539746],
#        ["Children's", 2.2459045299384788]], dtype=object)

# %%
major = []
mean_sim = []
for i in range(len(df_ve)):
    major.append(df_ve[i,0])
    mean_sim.append(df_ve[i,1])

# %%
plt.xticks(rotation = 90)
plt.plot(major,mean_sim)
