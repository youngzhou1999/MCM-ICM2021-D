# %%
import pandas as pd

# %%
df = pd.read_csv('data_by_artist.csv')
df_info = pd.read_csv('info.csv')

# %%
df # mean value of artist
# Out:
#              artist_name  artist_id  danceability    energy   valence  \
# 0          Frank Sinatra     792507      0.384478  0.238017  0.364288
# 1      Vladimir Horowitz     119107      0.343210  0.118844  0.225951
# 2            Johnny Cash     816890      0.619803  0.449381  0.680662
# 3         Billie Holiday      79016      0.572637  0.201368  0.498934
# 4              Bob Dylan      66915      0.512598  0.477932  0.551934
# ...                  ...        ...           ...       ...       ...
# 5849     Natalie La Rose    3359519      0.830000  0.520000  0.735000
# 5850          Sarah Ross    3381566      0.721000  0.944000  0.626000
# 5851              Rotimi    3410250      0.637000  0.501000  0.431000
# 5852  Jillian Jacqueline    3455945      0.547000  0.672000  0.283000
# 5853         Jaira Burns    3639618      0.566000  0.769000  0.385000
#
#            tempo   loudness  mode  key  acousticness  instrumentalness  \
# ...

# %%
df_info = df_info.rename(columns={'2':'genre','1':'active_start','0':'name','Unnamed: 0':'id'})

# %%
df_info.loc[0][0]
# Out:
# 74

# %%
col=['danceability','energy','valence','tempo','loudness','mode','key','acousticness','instrumentalness','liveness','speechiness','duration_ms','popularity','count']

# %%
col_c=['danceability','energy','valence','tempo','loudness','mode','key']
col_v=['acousticness','instrumentalness','liveness','speechiness']
col_d = ['duration_ms','popularity','count']

# %%
df_c=df[col_c]
df_v = df[col_v]
df_d = df[col_d]

# %%
X_c = df_c.to_numpy()

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler()
X_c = scaler.fit_transform(X_c)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
import seaborn as sns

# %%
pca = PCA(n_components=6)
pca.fit(X)
# Reduce dimensionality of X
X_reduced = pca.transform(X)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.22737875, 0.12255048, 0.10038559, 0.09126714, 0.07333463,
#        0.0702334 ])

# %%
X_reduced
# Out:
# array([[-5.71544247e+04,  1.33303508e+03],
#        [ 2.02067809e+04,  1.17450097e+03],
#        [-8.40550735e+04,  1.06705587e+03],
#        ...,
#        [-6.08733007e+04, -3.56320614e+01],
#        [-3.32013016e+04, -3.48501869e+01],
#        [-5.52343018e+04, -3.60791548e+01]])

# %%
X_re=pca.inverse_transform(X_reduced)
# Out:
# array([[ 4.16357416e-01,  2.11980391e-01,  4.71992368e-01, ...,
#          1.89179926e+05,  1.18107958e+01,  1.36868454e+03],
#        [ 4.22343397e-01,  2.47990140e-01,  4.42939972e-01, ...,
#          2.66541125e+05,  1.55910862e+01,  1.20741226e+03],
#        [ 4.47170976e-01,  2.91063125e-01,  5.07080924e-01, ...,
#          1.62279267e+05,  1.70963887e+01,  1.10374244e+03],
#        ...,
#        [ 5.57060730e-01,  6.02873498e-01,  5.80482120e-01, ...,
#          1.85461000e+05,  3.99176992e+01,  5.13204852e-01],
#        [ 5.53312530e-01,  5.99353725e-01,  5.65616699e-01, ...,
#          2.13132999e+05,  4.00882519e+01,  3.00426799e-01],
#        [ 5.56359045e-01,  6.02329238e-01,  5.77500033e-01, ...,
#          1.91099999e+05,  3.99649190e+01, -1.36418356e-01]])

# %%
df_info_ve = df_info.to_numpy()
df_ve = df.to_numpy()

# %%
df_info_ve[0][0]
# Out:
# 74

# %%
df_ve[0][1]
# Out:
# 792507
